# %%
# -*- coding: utf-8
# Abraji (https://www.abraji.org.br)
# Reinaldo Chaves (reinaldo@abraji.org.br)
# Programa 02 do curso Como usar Python para descobrir uma rede de interesses
#

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# # Cria arquivos com dados das doações de campanhas nas eleições de 2010, 2014 e 2018

# %% [markdown]
# Fonte: http://www.tse.jus.br/eleicoes/estatisticas/repositorio-de-dados-eleitorais-1/repositorio-de-dados-eleitorais

# %% [markdown]
# # 2010

# %%
def _reader_2010(fname):
    return pd.read_csv(fname,\
                       sep=';', \
                       encoding='latin_1', \
                       converters={'cpf_candidato': lambda x: str(x),
                                   'sequencial': lambda x: str(x),\
                                   'cpf_cnpj_doador': lambda x: str(x)}, \
                       decimal=',',\
                       header=0,\
                       names=['data_hora',
                              'sequencial',
                              'uf',
                              'partido_eleicao',
                              'numero_candidato',
                              'cargo',
                              'nome_candidato',
                              'cpf_candidato',
                              'entrega_conjunto',
                              'recibo_eleitoral',
                              'numero_documento',
                              'cpf_cnpj_doador',
                              'nome_doador',
                              'data_receita',
                              'valor_receita',
                              'tipo_receita',
                              'fonte_recurso',
                              'especie_recurso',
                              'descricao_receita'])

# %%
folder = Path("doacoes/2010")
doacoes_2010 = pd.concat([
    _reader_2010(csv)
    for csv in folder.glob("*.txt")
])

# %%
doacoes_2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 427017 entries, 0 to 12359
# Data columns (total 19 columns):
# data_hora            427017 non-null object
# sequencial           427017 non-null object
# uf                   427017 non-null object
# partido_eleicao      427017 non-null object
# numero_candidato     427017 non-null object
# cargo                427017 non-null object
# nome_candidato       427017 non-null object
# cpf_candidato        427017 non-null object
# entrega_conjunto     427017 non-null object
# recibo_eleitoral     426186 non-null float64
# numero_documento     167807 non-null object
# cpf_cnpj_doador      427017 non-null object
# nome_doador          426636 non-null object
# data_receita         427017 non-null object
# valor_receita        427017 non-null float64
# tipo_receita         427017 non-null object
# fonte_recurso        427017 non-null object
# especie_recurso      427017 non-null object
# descricao_receita    427017 non-null object
# ...

# %%
doacoes_2010.head()
# Out:
#             data_hora   sequencial  uf partido_eleicao  numero_candidato  \
# 0  13/11/201701:00:21  20000000059  AL             PTB                14
# 1  13/11/201701:00:21  20000000059  AL             PTB                14
# 2  13/11/201701:00:21  20000000059  AL             PTB                14
# 3  13/11/201701:00:21  20000000059  AL             PTB                14
# 4  13/11/201701:00:21  20000000059  AL             PTB                14
#
#         cargo                    nome_candidato cpf_candidato  \
# 0  Governador  FERNANDO AFFONSO COLLOR DE MELLO   02906287172
# 1  Governador  FERNANDO AFFONSO COLLOR DE MELLO   02906287172
# 2  Governador  FERNANDO AFFONSO COLLOR DE MELLO   02906287172
# 3  Governador  FERNANDO AFFONSO COLLOR DE MELLO   02906287172
# 4  Governador  FERNANDO AFFONSO COLLOR DE MELLO   02906287172
#
#   entrega_conjunto  recibo_eleitoral numero_documento cpf_cnpj_doador  \
# 0              Nao      1.400006e+10              NaN  01291022000110
# ...

# %%
doacoes_2010.to_csv('resultados/doacoes_2010.csv', index=False, decimal=',')

# %% [markdown]
# # 2014

# %%
doacoes_2014 = pd.read_csv('doacoes/2014/receitas_candidatos_2014_brasil.txt',\
                           sep=';',\
                           encoding = 'latin_1',\
                           converters={'sequencial': lambda x: str(x),
                                       'cpf_candidato': lambda x: str(x), 
                                       'cpf_cnpj_doador': lambda x: str(x),
                                       'cpf_cnpj_doador_originario': lambda x: str(x)},\
                           decimal=',',\
                           header=0,\
                           names=['cod_eleicao',
                                 'desc_eleicao',
                                 'data_hora', 
                                 'cnpj_prestador_conta',
                                 'sequencial', 
                                 'uf',
                                 'partido_eleicao', 
                                 'numero_candidato',
                                 'cargo',
                                 'nome_candidato',
                                 'cpf_candidato',   
                                 'recibo_eleitoral',
                                 'numero_documento',
                                 'cpf_cnpj_doador',
                                 'nome_doador',
                                 'nome_doador_receita',
                                 'ue_doador',
                                 'numero_partido_doador',
                                 'numero_candidato_doador',
                                 'cod_setor_economico_doador',
                                 'setor_economico_doador',
                                 'data_receita',
                                 'valor_receita',
                                 'tipo_receita',
                                 'fonte_recurso',
                                 'especie_recurso',
                                 'descricao_receita',
                                 'cpf_cnpj_doador_originario',
                                 'nome_doador_originario',
                                 'tipo_doador_originario',
                                 'setor_economico_doador_originario',
                                 'nome_doador_originario_receita'])

# %%
doacoes_2014.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 427489 entries, 0 to 427488
# Data columns (total 32 columns):
# cod_eleicao                          427489 non-null int64
# desc_eleicao                         427489 non-null object
# data_hora                            427489 non-null object
# cnpj_prestador_conta                 427489 non-null int64
# sequencial                           427489 non-null object
# uf                                   427489 non-null object
# partido_eleicao                      427489 non-null object
# numero_candidato                     427489 non-null int64
# cargo                                427489 non-null object
# nome_candidato                       427489 non-null object
# cpf_candidato                        427489 non-null object
# recibo_eleitoral                     427489 non-null object
# numero_documento                     427472 non-null object
# cpf_cnpj_doador                      427489 non-null object
# ...

# %%
doacoes_2014.head()
# Out:
#    cod_eleicao          desc_eleicao           data_hora  \
# 0          143  Eleições Gerais 2014  09/07/201617:15:01
# 1          143  Eleições Gerais 2014  09/07/201617:15:01
# 2          143  Eleições Gerais 2014  09/07/201617:15:01
# 3          143  Eleições Gerais 2014  09/07/201617:15:01
# 4          143  Eleições Gerais 2014  09/07/201617:15:01
#
#    cnpj_prestador_conta    sequencial  uf partido_eleicao  numero_candidato  \
# 0        20578194000114   90000000637  GO            PSDB                45
# 1        20571797000194   90000000725  GO             PSD              5555
# 2        20578262000145  180000000046  PI             PSB               400
# 3        20603227000139  180000000044  PI            PMDB                15
# 4        20603227000139  180000000044  PI            PMDB                15
#
#               cargo                      nome_candidato  ... valor_receita  \
# 0        Governador     MARCONI FERREIRA PERILLO JUNIOR  ...      145000.0
# ...

# %%
doacoes_2014.to_csv('resultados/doacoes_2014.csv', index=False, decimal=',')

# %% [markdown]
# # 2018

# %%
doacoes_2018_bruto = pd.read_csv('doacoes/2018/receitas_candidatos_2018_BRASIL.csv',\
                           sep=';',\
                           encoding = 'latin_1',\
                           converters={'SQ_CANDIDATO': lambda x: str(x),
                                       'NR_CPF_CANDIDATO': lambda x: str(x), 
                                       'NR_CPF_CNPJ_DOADOR': lambda x: str(x)},\
                           decimal=',')

# %%
doacoes_2018_bruto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321140 entries, 0 to 321139
# Data columns (total 57 columns):
# DT_GERACAO                     321140 non-null object
# HH_GERACAO                     321140 non-null object
# ANO_ELEICAO                    321140 non-null int64
# CD_TIPO_ELEICAO                321140 non-null int64
# NM_TIPO_ELEICAO                321140 non-null object
# CD_ELEICAO                     321140 non-null int64
# DS_ELEICAO                     321140 non-null object
# DT_ELEICAO                     321140 non-null object
# ST_TURNO                       321140 non-null int64
# TP_PRESTACAO_CONTAS            321140 non-null object
# DT_PRESTACAO_CONTAS            321140 non-null object
# SQ_PRESTADOR_CONTAS            321140 non-null int64
# SG_UF                          321140 non-null object
# SG_UE                          321140 non-null object
# NM_UE                          321140 non-null object
# ...

# %%
doacoes_2018_bruto.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO NM_TIPO_ELEICAO  \
# 0  06/06/2019   02:59:15         2018                2       Ordinária
# 1  06/06/2019   02:59:15         2018                2       Ordinária
# 2  06/06/2019   02:59:15         2018                2       Ordinária
# 3  06/06/2019   02:59:15         2018                2       Ordinária
# 4  06/06/2019   02:59:15         2018                2       Ordinária
#
#    CD_ELEICAO                  DS_ELEICAO  DT_ELEICAO  ST_TURNO  \
# 0         297  Eleição Geral Federal 2018  07/10/2018         1
# 1         297  Eleição Geral Federal 2018  07/10/2018         1
# 2         297  Eleição Geral Federal 2018  07/10/2018         1
# 3         297  Eleição Geral Federal 2018  07/10/2018         1
# 4         297  Eleição Geral Federal 2018  07/10/2018         1
#
#     TP_PRESTACAO_CONTAS  ... DS_CARGO_CANDIDATO_DOADOR  NR_PARTIDO_DOADOR  \
# 0               Parcial  ...                    #NULO#                 44
# ...

# %%
doacoes_2018 = doacoes_2018_bruto.drop(['DT_GERACAO', 
                          'HH_GERACAO',
                          'ANO_ELEICAO',
                          'CD_TIPO_ELEICAO',
                          'NM_TIPO_ELEICAO',
                          'CD_ELEICAO',
                          'DS_ELEICAO',
                          'DT_ELEICAO',
                          'ST_TURNO',
                          'TP_PRESTACAO_CONTAS',
                          'DT_PRESTACAO_CONTAS',
                          'SQ_PRESTADOR_CONTAS',
                          'SG_UE',
                          'NM_UE',
                          'NR_CNPJ_PRESTADOR_CONTA',
                          'CD_CARGO',
                          'NR_PARTIDO',
                          'NM_PARTIDO',
                          'CD_FONTE_RECEITA',
                          'DS_FONTE_RECEITA',
                          'CD_ORIGEM_RECEITA',
                          'DS_ORIGEM_RECEITA',
                          'CD_NATUREZA_RECEITA',
                          'DS_NATUREZA_RECEITA',
                          'CD_ESPECIE_RECEITA',
                          'DS_ESPECIE_RECEITA',
                          'CD_ESFERA_PARTIDARIA_DOADOR',
                          'SG_UF_DOADOR',
                          'CD_MUNICIPIO_DOADOR',
                          'NM_MUNICIPIO_DOADOR',
                          'NR_CANDIDATO_DOADOR',
                          'NR_PARTIDO_DOADOR',
                          'SG_PARTIDO_DOADOR',
                          'NM_PARTIDO_DOADOR',
                          'NR_RECIBO_DOACAO',
                          'NR_DOCUMENTO_DOACAO',
                          'SQ_RECEITA',
                        ] , axis=1)

# %%
doacoes_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 321140 entries, 0 to 321139
# Data columns (total 20 columns):
# SG_UF                          321140 non-null object
# DS_CARGO                       321140 non-null object
# SQ_CANDIDATO                   321140 non-null object
# NR_CANDIDATO                   321140 non-null int64
# NM_CANDIDATO                   321140 non-null object
# NR_CPF_CANDIDATO               321140 non-null object
# NR_CPF_VICE_CANDIDATO          321140 non-null int64
# SG_PARTIDO                     321140 non-null object
# CD_CNAE_DOADOR                 321140 non-null int64
# DS_CNAE_DOADOR                 321140 non-null object
# NR_CPF_CNPJ_DOADOR             321140 non-null object
# NM_DOADOR                      321140 non-null object
# NM_DOADOR_RFB                  321140 non-null object
# DS_ESFERA_PARTIDARIA_DOADOR    321140 non-null object
# SQ_CANDIDATO_DOADOR            321140 non-null int64
# ...

# %%
doacoes_2018.head()
# Out:
#   SG_UF           DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0    RS   Deputado Federal  210000616466          4412
# 1    MT   Deputado Federal  110000622015          1881
# 2    MT   Deputado Federal  110000622015          1881
# 3    PI  Deputado Estadual  180000625884         90000
# 4    MG  Deputado Estadual  130000610130         51360
#
#                    NM_CANDIDATO NR_CPF_CANDIDATO  NR_CPF_VICE_CANDIDATO  \
# 0             SANDRA SILVA FAVA      56133286091                     -1
# 1     RAFAELE GOMES DE OLIVEIRA      45190658104                     -1
# 2     RAFAELE GOMES DE OLIVEIRA      45190658104                     -1
# 3  JOSÉ AGOSTINHO NUNES MOREIRA      06659047387                     -1
# 4   FERNANDO MENDES VASCONCELOS      01233349694                     -1
#
#   SG_PARTIDO  CD_CNAE_DOADOR                        DS_CNAE_DOADOR  \
# 0        PRP           94928  Atividades de organizações políticas
# ...

# %%
doacoes_2018.to_csv('resultados/doacoes_2018.csv', index=False, decimal=',')

# %% [markdown]
# # Cria arquivo com candidatos em 2018

# %%
candidatos = pd.read_csv('candidatos/consulta_cand_2018_BRASIL.csv',\
                         sep=';',\
                         encoding = 'latin_1',\
                         converters={'SQ_CANDIDATO': lambda x: str(x),
                                     'NR_CPF_CANDIDATO': lambda x: str(x),
                                     'NR_TITULO_ELEITORAL_CANDIDATO': lambda x: str(x),
                                    })

# %%
candidatos = candidatos.drop(['DT_GERACAO', 
                              'SG_UE',
                                        'HH_GERACAO',
                                        'ANO_ELEICAO',
                                        'CD_TIPO_ELEICAO',
                                        'NM_TIPO_ELEICAO',
                                        'NR_TURNO', 
                                        'CD_ELEICAO',
                                        'DS_ELEICAO',
                                        'DT_ELEICAO',
                                        'TP_ABRANGENCIA', 
                                        'NM_UE',
                                        'CD_CARGO',
                                        'NM_EMAIL',
                                        'CD_SITUACAO_CANDIDATURA', 
                                        'CD_DETALHE_SITUACAO_CAND',
                                        'DS_DETALHE_SITUACAO_CAND',
                                        'TP_AGREMIACAO',
                                        'NR_PARTIDO',
                                        'NM_PARTIDO',
                                        'SQ_COLIGACAO',
                                        'NM_COLIGACAO',
                                        'DS_COMPOSICAO_COLIGACAO',
                                        'CD_NACIONALIDADE',
                                        'DS_NACIONALIDADE',
                                        'SG_UF_NASCIMENTO',  
                                        'CD_MUNICIPIO_NASCIMENTO',
                                        'NM_MUNICIPIO_NASCIMENTO', 
                                        'NR_IDADE_DATA_POSSE',      
                                        'CD_GENERO',
                                        'CD_GRAU_INSTRUCAO',      
                                        'DS_GRAU_INSTRUCAO',            
                                        'CD_ESTADO_CIVIL',            
                                        'DS_ESTADO_CIVIL',       
                                        'CD_COR_RACA',    
                                        'DS_COR_RACA',                   
                                        'CD_OCUPACAO',     
                                        'DS_OCUPACAO',              
                                        'NR_DESPESA_MAX_CAMPANHA',     
                                        'CD_SIT_TOT_TURNO' ,     
                                        'ST_REELEICAO',
                                        'ST_DECLARAR_BENS',                 
                                        'NR_PROTOCOLO_CANDIDATURA',         
                                        'NR_PROCESSO'] , axis=1)

# %%
candidatos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29145 entries, 0 to 29144
# Data columns (total 14 columns):
# SG_UF                            29145 non-null object
# DS_CARGO                         29145 non-null object
# SQ_CANDIDATO                     29145 non-null object
# NR_CANDIDATO                     29145 non-null int64
# NM_CANDIDATO                     29145 non-null object
# NM_URNA_CANDIDATO                29145 non-null object
# NM_SOCIAL_CANDIDATO              29145 non-null object
# NR_CPF_CANDIDATO                 29145 non-null object
# DS_SITUACAO_CANDIDATURA          29145 non-null object
# SG_PARTIDO                       29145 non-null object
# DT_NASCIMENTO                    29145 non-null object
# NR_TITULO_ELEITORAL_CANDIDATO    29145 non-null object
# DS_GENERO                        29145 non-null object
# DS_SIT_TOT_TURNO                 29145 non-null object
# dtypes: int64(1), object(13)
# memory usage: 3.1+ MB

# %%
candidatos.reset_index().head()
# Out:
#    index SG_UF           DS_CARGO  SQ_CANDIDATO  NR_CANDIDATO  \
# 0      0    RR   DEPUTADO FEDERAL  230000614403          1918
# 1      1    PA  DEPUTADO ESTADUAL  140000604447         50321
# 2      2    PB  DEPUTADO ESTADUAL  150000604388         90999
# 3      3    PA  DEPUTADO ESTADUAL  140000604226         22221
# 4      4    AC        1º SUPLENTE   10000615658           131
#
#                                 NM_CANDIDATO   NM_URNA_CANDIDATO  \
# 0                      JOÃO BATISTA CATALANO  PROFESSOR CATALANO
# 1               ANTONIO MILTON DO NASCIMENTO      ANTONIO MILTON
# 2                        TANIA MIGUEL DUARTE           DRA TANIA
# 3                JAQUELINE BORGES DE ALMEIDA           JAQUELINE
# 4  MARIA DE NAZARETH MELLO DE ARAÚJO LAMBERT     NAZARETH ARAÚJO
#
#   NM_SOCIAL_CANDIDATO NR_CPF_CANDIDATO DS_SITUACAO_CANDIDATURA SG_PARTIDO  \
# 0              #NULO#      12031161873                  INAPTO       PODE
# ...

# %%
candidatos.to_csv('resultados/candidatos_2018.csv', index=False, decimal=',')
